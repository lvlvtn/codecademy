# %% [markdown]
# # Visualizing Loans Awarded by Kiva
#
# The Codeacademy Off Platform Project on visualization with Seaborn. <a href="https://www.kiva.org/">Kiva</a> is a non-profit organization that allows people to lend money via the Internet to low-income entrepreneurs and students in 77 countries. The visualization revealed strong gender inequality.
#
# The dataset contains information about loans awarded by Kita downloaded from <a href="https://www.kaggle.com/fkosmowski/kivadhsv1" >Kaggle</a> and simplified by Codecademy.
#
# Tasks:
# - explore the average loan amount by country using aggregated bar charts
# - visualize the distribution of loan amounts by project type and gender using box plots and violin plots

# %% [markdown]
# ## Import Python libraries and download the data

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('kiva_data.csv')
df.head()
# Out:
#    loan_amount               activity   country  gender
# 0          625  Food Production/Sales  Pakistan  female
# 1          250  Food Production/Sales  Pakistan  female
# 2          400  Food Production/Sales  Pakistan  female
# 3          400  Food Production/Sales  Pakistan  female
# 4          500  Food Production/Sales  Pakistan  female

# %% [markdown]
# ## Examine The Data

# %%
df.head(10)
# Out:
#    loan_amount               activity   country  gender
# 0          625  Food Production/Sales  Pakistan  female
# 1          250  Food Production/Sales  Pakistan  female
# 2          400  Food Production/Sales  Pakistan  female
# 3          400  Food Production/Sales  Pakistan  female
# 4          500  Food Production/Sales  Pakistan  female
# 5          500  Food Production/Sales  Pakistan  female
# 6          400  Food Production/Sales  Pakistan  female
# 7          500  Food Production/Sales  Pakistan  female
# 8          400  Food Production/Sales  Pakistan  female
# 9          450  Food Production/Sales  Pakistan  female

# %%
sns.distplot(df['loan_amount'])
plt.xlabel('Loan amount')
# Out:
# Text(0.5, 0, 'Loan amount')

# %% [markdown]
# ## Simple Bar Charts

# %%
import matplotlib.ticker as mtick

# Creates the figure
f, ax = plt.subplots(figsize=(10, 8))

# Plot the data
sns.barplot(data=df, x="country", y = "loan_amount")

# Format the y-axis ticks to add $ (units of USD)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
ax.set(xlabel='Country', ylabel='Loan amount')
# Out:
# [Text(0, 0.5, 'Loan amount'), Text(0.5, 0, 'Country')]

# %%
import matplotlib.ticker as mtick

# Creates the figure
f, ax = plt.subplots(figsize=(10, 8))

# Plot the data
sns.barplot(data=df, x="activity", y = "loan_amount")

# Format the y-axis ticks to add $ (units of USD)
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
ax.set(xlabel=' ', ylabel='Loan amount')
# Out:
# [Text(0, 0.5, 'Loan amount'), Text(0.5, 0, ' ')]

# %% [markdown]
# ## Adding `hue` to the Visualization

# %%
f, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df, x="country", y="loan_amount", hue='gender')

fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
ax.set(xlabel=' ', ylabel='Loan amount')
# Out:
# [Text(0, 0.5, 'Loan amount'), Text(0.5, 0, ' ')]

# %%
f, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df, x="activity", y="loan_amount", hue='gender')

fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
ax.set(xlabel=' ', ylabel='Loan amount')
# Out:
# [Text(0, 0.5, 'Loan amount'), Text(0.5, 0, ' ')]

# %% [markdown]
# ## Styling

# %%
# Set color palette
sns.set_palette('Pastel1')

# Set style
sns.set_style('darkgrid')

# Create figure and axes
plt.figure(figsize=(25, 15))

# Add a title
ax.set_title("Loan amount by country and gender", fontsize=12)

# Use Seaborn to create the bar plot
f, ax = plt.subplots(figsize=(15, 10))

sns.barplot(data=df, x="country", y="loan_amount", hue='gender')

fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

# %% [markdown]
# ## Box Plots

# %%
plt.figure(figsize=(16, 10))

sns.boxplot(data=df, x="country", y="loan_amount", hue='gender')

# %% [markdown]
# ## Box Plot by Activity

# %%
plt.figure(figsize=(16, 10))

sns.boxplot(data=df, x="activity", y="loan_amount", hue='gender')

# %% [markdown]
# ## Violin Plots

# %%
plt.figure(figsize=(16, 10))

sns.violinplot(data=df, x="activity", y="loan_amount")

# %% [markdown]
# ### Violin plot that visualizes the distribution of loan amount by country

# %%
plt.figure(figsize=(16, 10))

sns.violinplot(data=df, x="country", y="loan_amount")

# %% [markdown]
# ## Split Violin Plots

# %%
plt.figure(figsize=(18, 12))
sns.violinplot(data=df, x="country", y="loan_amount", hue='gender')
